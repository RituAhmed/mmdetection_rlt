# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file = 'configs/faster_rcnn/faster_rcnn_r50_fpn_1x_rlt.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
# url: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
#checkpoint_file = 'checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'
checkpoint_file = 'C:/Users/ritua/Documents/GitHub/AI-to-detect-refrigeration-and-air-conditioning-on-Sa-satellite-images/work_dirs/faster_rcnn_r50_fpn_1x_rlt/latest.pth'

# %%
model = init_detector(config_file, checkpoint_file, device='cpu')
# Out:
# load checkpoint from local path: C:/Users/ritua/Documents/GitHub/AI-to-detect-refrigeration-and-air-conditioning-on-Sa-satellite-images/work_dirs/faster_rcnn_r50_fpn_1x_rlt/latest.pth

# %%
img = 'demo/test20.jpg'
result = inference_detector(model, img)

# %%
show_result_pyplot(model, img, result)
